# %% [markdown]
# # Experimentando con Colab

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 10*np.pi, 1000)
y = np.sin(x)
plt.plot(x,y)

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.2.0

# %% [markdown]
# ## Método 1, importando desde link

# %%
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/arrhythmia/arrhythmia.data
# Out:
# --2020-06-18 04:57:10--  https://archive.ics.uci.edu/ml/machine-learning-databases/arrhythmia/arrhythmia.data
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 402355 (393K) [application/x-httpd-php]
# Saving to: ‘arrhythmia.data.1’
#
# arrhythmia.data.1   100%[===================>] 392.92K   709KB/s    in 0.6s
#
# 2020-06-18 04:57:11 (709 KB/s) - ‘arrhythmia.data.1’ saved [402355/402355]

# %%
# !ls
# Out:
# arrhythmia.data  arrhythmia.data.1  drive  notebooks  sample_data

# %%
import pandas as pd
data = pd.read_csv('arrhythmia.data', header=None)

# %%
df = data[[0,1,2,3,4,5]]
df.columns = ['age', 'sex', 'height', 'weight', 'QRS Duration', 'P-R interval']

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [18,18]
df.hist();

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df);

# %% [markdown]
# ## Método 2, desde keras.utils

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data'

tf.keras.utils.get_file('rauto-mpg.data', url)
# Out:
# ...
# 32768/30286 [================================] - 0s 4us/step
# '/root/.keras/datasets/rauto-mpg.data'

# %%
# !head /root/.keras/datasets/rauto-mpg.data
# Out:
# 18.0   8   307.0      130.0      3504.      12.0   70  1	"chevrolet chevelle malibu"
# 15.0   8   350.0      165.0      3693.      11.5   70  1	"buick skylark 320"
# 18.0   8   318.0      150.0      3436.      11.0   70  1	"plymouth satellite"
# 16.0   8   304.0      150.0      3433.      12.0   70  1	"amc rebel sst"
# 17.0   8   302.0      140.0      3449.      10.5   70  1	"ford torino"
# 15.0   8   429.0      198.0      4341.      10.0   70  1	"ford galaxie 500"
# 14.0   8   454.0      220.0      4354.       9.0   70  1	"chevrolet impala"
# 14.0   8   440.0      215.0      4312.       8.5   70  1	"plymouth fury iii"
# 14.0   8   455.0      225.0      4425.      10.0   70  1	"pontiac catalina"
# 15.0   8   390.0      190.0      3850.       8.5   70  1	"amc ambassador dpl"

# %%
df_t = pd.read_csv('/root/.keras/datasets/rauto-mpg.data', header= None, delim_whitespace=True)
df_t.head()
# Out:
#       0  1      2      3       4     5   6  7                          8
# 0  18.0  8  307.0  130.0  3504.0  12.0  70  1  chevrolet chevelle malibu
# 1  15.0  8  350.0  165.0  3693.0  11.5  70  1          buick skylark 320
# 2  18.0  8  318.0  150.0  3436.0  11.0  70  1         plymouth satellite
# 3  16.0  8  304.0  150.0  3433.0  12.0  70  1              amc rebel sst
# 4  17.0  8  302.0  140.0  3449.0  10.5  70  1                ford torino

# %% [markdown]
# ## Método 3, desde equipo local

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-bb70cf95-870b-4add-ae4f-88c341198f25" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bb70cf95-870b-4add-ae4f-88c341198f25">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving daily-minimum-temperatures-in-me.csv to daily-minimum-temperatures-in-me.csv

# %%
df_t2 = pd.read_csv('daily-minimum-temperatures-in-me.csv', error_bad_lines=False)
df_t2.head()
# Out:
# b'Skipping line 3653: expected 2 fields, saw 3\n'
#          Date Daily minimum temperatures in Melbourne, Australia, 1981-1990
# 0  1981-01-01                                               20.7
# 1  1981-01-02                                               17.9
# 2  1981-01-03                                               18.8
# 3  1981-01-04                                               14.6
# 4  1981-01-05                                               15.8

# %% [markdown]
# ## Método 4 funciones o código local

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ffd3f948-051c-429e-819c-59c139324b8b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ffd3f948-051c-429e-819c-59c139324b8b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving fake_util.py to fake_util.py

# %%
from fake_util import my_useful_function
my_useful_function()
# Out:
# hello world

# %%
# !pwd
# Out:
# /content

# %% [markdown]
# ## Método 5, archivos de google drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ls '/content/gdrive/My Drive/Colab Notebooks'
# Out:
# ls: cannot access '/content/gdrive/My Drive/Colab Notebooks': No such file or directory
